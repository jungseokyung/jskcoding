# %%
import pandas as pd

# %%
성연령1701=pd.read_csv(r'C:\Users\Jungsk\Downloads\1_(SKT) 2019 공공데이터활용 빅데이터 분석 공모전용 민간데이터\1) 성연령유동\FLOW_AGE_201701.csv',sep='|')

# %%
성연령1701.head(5)
# Out:
#    STD_YM              BLOCK_CD        X_COORD       Y_COORD  \
# 0  201701  11130710300010000001  947233.991787  1.953129e+06
# 1  201701  11130710300010000001  947233.991787  1.953179e+06
# 2  201701  11130710300010000001  947233.991787  1.953229e+06
# 3  201701  11130710300010000001  947283.991787  1.953079e+06
# 4  201701  11130710300010000001  947283.991787  1.953129e+06
#
#    MAN_FLOW_POP_CNT_10G  MAN_FLOW_POP_CNT_20G  MAN_FLOW_POP_CNT_30G  \
# 0                  5.34                 16.73                 31.61
# 1                  3.14                  9.62                 19.11
# 2                  6.68                 21.64                 40.64
# 3                  3.51                 13.09                 15.73
# 4                  0.00                  2.77                  4.07
#
#    MAN_FLOW_POP_CNT_40G  MAN_FLOW_POP_CNT_50G  MAN_FLOW_POP_CNT_60GU  \
# 0                 37.52                 35.17                  29.62
# ...

# %%
시간대1701=pd.read_csv(r'C:\Users\Jungsk\Downloads\1_(SKT) 2019 공공데이터활용 빅데이터 분석 공모전용 민간데이터\2) 시간대유동\FLOW_TIME_201701.csv',sep='|')

# %%
시간대1701.head(5)
# Out:
#    STD_YM              BLOCK_CD        X_COORD       Y_COORD  TMST_00  \
# 0  201701  11130710300010000001  947233.991787  1.953129e+06     4.01
# 1  201701  11130710300010000001  947233.991787  1.953179e+06     2.10
# 2  201701  11130710300010000001  947233.991787  1.953229e+06     4.81
# 3  201701  11130710300010000001  947283.991787  1.953079e+06     1.17
# 4  201701  11130710300010000001  947283.991787  1.953129e+06     0.50
#
#    TMST_01  TMST_02  TMST_03  TMST_04  TMST_05  ...  TMST_14  TMST_15  \
# 0     2.64     2.03     1.71     1.99     3.36  ...    14.07    13.85
# 1     1.48     1.21     1.03     1.20     1.81  ...     8.37     8.09
# 2     3.17     2.38     2.03     2.38     3.85  ...    18.78    17.66
# 3     0.84     0.65     0.62     0.75     1.75  ...     7.31     7.64
# 4     0.35     0.23     0.20     0.25     0.48  ...     2.03     1.85
#
#    TMST_16  TMST_17  TMST_18  TMST_19  TMST_20  TMST_21  TMST_22  TMST_23
# ...

# %%
요일별1701=pd.read_csv(r'C:\Users\Jungsk\Downloads\1_(SKT) 2019 공공데이터활용 빅데이터 분석 공모전용 민간데이터\3) 요일별유동\FLOW_WKDY_201701.csv',sep='|')

# %%
요일별1701.head(5)
# Out:
#    STD_YM              BLOCK_CD        X_COORD       Y_COORD  \
# 0  201701  11130710300010000001  947233.991787  1.953129e+06
# 1  201701  11130710300010000001  947233.991787  1.953179e+06
# 2  201701  11130710300010000001  947233.991787  1.953229e+06
# 3  201701  11130710300010000001  947283.991787  1.953079e+06
# 4  201701  11130710300010000001  947283.991787  1.953129e+06
#
#    FLOW_POP_CNT_MON  FLOW_POP_CNT_TUS  FLOW_POP_CNT_WED  FLOW_POP_CNT_THU  \
# 0            269.11            284.89            302.05            302.83
# 1            139.18            146.15            155.47            156.27
# 2            348.30            357.67            387.07            389.14
# 3            143.76            151.64            157.38            158.37
# 4             38.80             41.01             43.70             42.86
#
#    FLOW_POP_CNT_FRI  FLOW_POP_CNT_SAT  FLOW_POP_CNT_SUN
# 0            270.54            210.60            154.35
# ...

# %%
나이성별=pd.read_csv(r'C:\Users\Jungsk\Downloads\1_(SKT) 2019 공공데이터활용 빅데이터 분석 공모전용 민간데이터\4) 실근무인구_거주인구\DMP_SEX_AGE_POP_2017.csv',sep='|')
나이성별.head(5)
# Out:
#    STD_YYYY              BLOCK_CD  INVT_YYYY  HHLD_CNT  POP_M_0009  \
# 0      2017  11010530100010000001       2017       1.2        0.12
# 1      2017  11010530100010000001       2017       0.6        0.06
# 2      2017  11010530100010000001       2017       0.6        0.06
# 3      2017  11010530100010000001       2017       0.6        0.06
# 4      2017  11010530100010000001       2017       0.6        0.05
#
#    POP_M_1019  POP_M_2024  POP_M_2529  POP_M_3034  POP_M_3539  ...  \
# 0        0.14        0.06        0.06        0.04        0.06  ...
# 1        0.07        0.03        0.03        0.02        0.03  ...
# 2        0.07        0.03        0.03        0.02        0.03  ...
# 3        0.07        0.03        0.03        0.02        0.03  ...
# 4        0.04        0.02        0.03        0.03        0.03  ...
#
#    POP_W_4044  POP_W_4549  POP_W_5054  POP_W_5559  POP_W_6064  POP_W_6500  \
# 0        0.20        0.16        0.12        0.06        0.10        0.28
# ...

# %%
나이성별.columns
# Out:
# Index(['STD_YYYY', 'BLOCK_CD', 'INVT_YYYY', 'HHLD_CNT', 'POP_M_0009',
#        'POP_M_1019', 'POP_M_2024', 'POP_M_2529', 'POP_M_3034', 'POP_M_3539',
#        'POP_M_4044', 'POP_M_4549', 'POP_M_5054', 'POP_M_5559', 'POP_M_6064',
#        'POP_M_6500', 'POP_W_0009', 'POP_W_1019', 'POP_W_2024', 'POP_W_2529',
#        'POP_W_3034', 'POP_W_3539', 'POP_W_4044', 'POP_W_4549', 'POP_W_5054',
#        'POP_W_5559', 'POP_W_6064', 'POP_W_6500', 'X_COORD', 'Y_COORD',
#        'BD_MGT_SN', 'DATA_LOAD_DT'],
#       dtype='object')

# %%
주간=pd.read_csv(r'C:\Users\Jungsk\Downloads\1_(SKT) 2019 공공데이터활용 빅데이터 분석 공모전용 민간데이터\4) 실근무인구_거주인구\DMP_WK_PLC_POP_2017.csv',sep='|')
주간.head(5)
# Out:
#    STD_YYYY              BLOCK_CD  INVT_YYYY  MAN_CNT_14_L  MAN_CNT_15_19  \
# 0      2017  11010530100010000001       2017           0.0            0.0
# 1      2017  11010530100010000001       2017           0.0            0.0
# 2      2017  11010530100010000001       2017           0.0            0.0
# 3      2017  11010530100010000001       2017           0.0            0.0
# 4      2017  11010530100010000001       2017           0.0            0.0
#
#    MAN_CNT_20_24  MAN_CNT_25_29  MAN_CNT_30_34  MAN_CNT_35_39  MAN_CNT_40_44  \
# 0            0.0           0.35           0.35           0.35           0.35
# 1            0.0           0.32           0.32           0.32           0.32
# 2            0.0           0.16           0.16           0.16           0.16
# 3            0.0           0.28           0.28           0.28           0.28
# 4            0.1           0.29           0.65           0.54           0.58
#
# ...

# %%
주간.columns
# Out:
# Index(['STD_YYYY', 'BLOCK_CD', 'INVT_YYYY', 'MAN_CNT_14_L', 'MAN_CNT_15_19',
#        'MAN_CNT_20_24', 'MAN_CNT_25_29', 'MAN_CNT_30_34', 'MAN_CNT_35_39',
#        'MAN_CNT_40_44', 'MAN_CNT_45_49', 'MAN_CNT_50_54', 'MAN_CNT_55_59',
#        'MAN_CNT_60_64', 'MAN_CNT_65_U', 'WMAN_CNT_14_L', 'WMAN_CNT_15_19',
#        'WMAN_CNT_20_24', 'WMAN_CNT_25_29', 'WMAN_CNT_30_34', 'WMAN_CNT_35_39',
#        'WMAN_CNT_40_44', 'WMAN_CNT_45_49', 'WMAN_CNT_50_54', 'WMAN_CNT_55_59',
#        'WMAN_CNT_60_64', 'WMAN_CNT_65_U', 'X_COORD', 'Y_COORD', 'BD_MGT_SN',
#        'DATA_LOAD_DT'],
#       dtype='object')

# %%
import numpy as np
import pandas as pd
import shapefile as shp
import matplotlib.pyplot as plt
import seaborn as sns

# %%
shp_path='C:\\Users\\Jungsk\\Downloads\\1_(SKT) 2019 공공데이터활용 빅데이터 분석 공모전용 민간데이터\\DMM_BLOCK\\DMM_BLOCK.SHP'
sf=shp.Reader(shp_path)

# %%
sf

# %%
from matplotlib  import pyplot as plt

# %%
import geopandas as gpd

# %%
shp_file='C:\\Users\\Jungsk\\Downloads\\1_(SKT) 2019 공공데이터활용 빅데이터 분석 공모전용 민간데이터\\DMM_BLOCK\\DMM_BLOCK.SHP'
shp_file=gpd.read_file(shp_file,encoding='euckr')
shp_file
# Out:
#      STD_YYYY              BLOCK_CD SIDO_CD SIDO_NM SGNG_CD  SGNG_NM  \
# 0        2019  11010530100010000001      11   서울특별시   11110      종로구
# 1        2019  11010530100020000001      11   서울특별시   11110      종로구
# 2        2019  11010530100030000001      11   서울특별시   11110      종로구
# 3        2019  11010530100040000001      11   서울특별시   11110      종로구
# 4        2019  11010530100050000001      11   서울특별시   11110      종로구
# 5        2019  11010530100050000002      11   서울특별시   11110      종로구
# 6        2019  11010530100050000003      11   서울특별시   11110      종로구
# 7        2019  11010530100050000004      11   서울특별시   11110      종로구
# 8        2019  11010530100050000005      11   서울특별시   11110      종로구
# 9        2019  11010530100050000006      11   서울특별시   11110      종로구
# 10       2019  11010530100050000007      11   서울특별시   11110      종로구
# 11       2019  11010530100050000008      11   서울특별시   11110      종로구
# 12       2019  11010530100050000009      11   서울특별시   11110      종로구
# ...

# %%
shp_file['STD_YYYY'].unique()
# Out:
# array(['2019'], dtype=object)

# %%
shp_file['']

# %%
shp_file['BLOCK_CD'].unique()
# Out:
# array(['11010530100010000001', '11010530100020000001',
#        '11010530100030000001', ..., '34012610606020000001',
#        '34012610606030000001', '34040120100020000001'], dtype=object)

# %%
shp_file['SIDO_NM'].unique()
# Out:
# array(['서울특별시', '경기도', '충청남도'], dtype=object)

# %%
shp_file['SIDO_CD'].unique()
# Out:
# array(['11', '41', '44'], dtype=object)

# %%
shp_file['SGNG_NM'].unique()
# Out:
# array(['종로구', '노원구', '서대문구', '성남시 수정구', '성남시 중원구', '성남시 분당구', '천안시 동남구',
#        '천안시 서북구'], dtype=object)

# %%
shp_file['ADONG_NM'].unique()
# Out:
# array(['사직동', '삼청동', '부암동', '평창동', '무악동', '교남동', '가회동', '종로1.2.3.4가동',
#        '종로5.6가동', '이화동', '창신1동', '창신2동', '창신3동', '숭인1동', '숭인2동', '청운효자동',
#        '혜화동', '월계1동', '월계2동', '월계3동', '공릉2동', '하계1동', '하계2동', '중계본동',
#        '중계1동', '중계4동', '상계1동', '상계2동', '상계5동', '상계3.4동', '상계8동', '상계9동',
#        '상계10동', '상계6.7동', '중계2.3동', '공릉1동', '천연동', '홍제1동', '홍제3동', '홍제2동',
#        '홍은1동', '홍은2동', '남가좌1동', '남가좌2동', '북가좌1동', '북가좌2동', '충현동', '북아현동',
#        '신촌동', '연희동', '신흥1동', '신흥2동', '신흥3동', '태평1동', '태평2동', '태평3동',
#        '태평4동', '수진1동', '수진2동', '단대동', '산성동', '양지동', '고등동', '시흥동', '복정동',
#        '위례동', '성남동', '금광1동', '금광2동', '은행1동', '은행2동', '상대원1동', '상대원2동',
#        '상대원3동', '하대원동', '도촌동', '중앙동', '분당동', '수내3동', '수내1동', '수내2동',
#        '정자2동', '정자3동', '서현1동', '서현2동', '이매1동', '이매2동', '야탑1동', '야탑3동',
#        '야탑2동', '구미동', '구미1동', '운중동', '금곡동', '삼평동', '판교동', '백현동', '정자1동',
#        '정자동', '목천읍', '풍세면', '광덕면', '북면', '성남면', '수신면', '병천면', '동면', '문성동',
# ...

# %%
shp_file['LDONG_NM'].unique()
# Out:
# array(['사직동', '필운동', '체부동', '통의동', '당주동', '내수동', '도렴동', '신문로2가', '신문로1가',
#        '세종로', '내자동', '적선동', '안국동', '송현동', '사간동', '화동', '소격동', '삼청동',
#        '팔판동', '신영동', '홍지동', '부암동', '구기동', '평창동', '무악동', '행촌동', '홍파동',
#        '평동', '교남동', '원서동', '가회동', '재동', '계동', '와룡동', '권농동', '종로3가', '묘동',
#        '봉익동', '인의동', '원남동', '훈정동', '중학동', '청진동', '수송동', '관훈동', '견지동',
#        '운니동', '경운동', '익선동', '돈의동', '낙원동', '공평동', '종로2가', '인사동', '관수동',
#        '관철동', '서린동', '장사동', '예지동', '종로4가', '충신동', '종로6가', '연지동', '종로5가',
#        '효제동', '이화동', '동숭동', '연건동', '창신동', '숭인동', '옥인동', '누하동', '청운동',
#        '누상동', '신교동', '통인동', '창성동', '궁정동', '효자동', '혜화동', '명륜1가', '명륜2가',
#        '명륜3가', '명륜4가', '월계동', '공릉동', '하계동', '중계동', '상계동', '현저동', '천연동',
#        '영천동', '냉천동', '옥천동', '홍제동', '홍은동', '남가좌동', '북가좌동', '충정로3가', '북아현동',
#        '충정로2가', '합동', '미근동', '대신동', '신촌동', '봉원동', '대현동', '창천동', '연희동',
#        '신흥동', '태평동', '수진동', '단대동', '산성동', '양지동', '심곡동', '오야동', '둔전동',
# ...

# %%
ax=shp_file.plot(figsize=(100,100),color="pink",edgecolor="k")
ax.set_title("Jong-ro & No one ")
ax.set_axis_off()
plt.show()

# %%
f=open(".txt",'r')
data=f.read()

print(data)
f.close()
