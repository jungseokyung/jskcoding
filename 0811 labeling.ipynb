# %%
df_daily['label_pm25'] = 0
df_daily['label_pm10'] = 0
df_temp0 = df_daily.loc[df_daily.pm25 <= 15,:]
df_temp0['label_pm25'] = 0
df_temp1 = df_daily.loc[df_daily.pm25 > 15,:]
df_temp1 = df_temp1.loc[df_temp1.pm25 <= 35,:]
df_temp1['label_pm25'] = 1
df_temp2 = df_daily.loc[df_daily.pm25 <= 75,:]
df_temp2 = df_temp2.loc[df_temp2.pm25 > 35,:]
df_temp2['label_pm25'] = 2
df_temp3 = df_daily.loc[df_daily.pm25 > 75,:]
df_temp3['label_pm25'] = 3
df_tp=df_temp0.append(df_temp1).append(df_temp2).append(df_temp3)
df_temp0 = df_tp.loc[df_tp.pm10 <= 30,:]
df_temp0['label_pm10'] = 0
df_temp1 = df_tp.loc[df_tp.pm10 > 30,:]
df_temp1 = df_temp1.loc[df_temp1.pm10 <= 80,:]
df_temp1['label_pm10'] = 1
df_temp2 = df_tp.loc[df_tp.pm10 <= 150,:]
df_temp2 = df_temp2.loc[df_temp2.pm10 > 80,:]
df_temp2['label_pm10'] = 2
df_temp3 = df_tp.loc[df_tp.pm10 > 150,:]
df_temp3['label_pm10'] = 3
df_daily=df_temp0.append(df_temp1).append(df_temp2).append(df_temp3)

# %%
import pandas as pd

blog=pd.read_csv(r'blog_2018.csv')

# %%
blog.head(5)
# Out:
#          date        author  \
# 0  2018-01-01       yts8600
# 1  2018-01-01    salley2005
# 2  2018-01-01        wtww23
# 3  2018-01-01      kiet1004
# 4  2018-01-01  dhlxhfdl1993
#
#                                              content  \
# 0  하남성 정주(郑州)를떠나 청도(青岛城阳)에서 일주일간 신규 한국식사우나 상담을 마치...
# 1  파주 감악산은 2014년 가을에 다녀온 적이 있는데 출렁다리가 생기면서 명소가 되어...
# 2  2018년을 마주하기 전 날, 바로 어제 작성하다 만 글을 해가 지나고 나서야 올리...
# 3  2018년 새해가 밝았습니다!! 무술년 황금 개띠라고 하네요:) 올해에는 뭘 해도 ...
# 4  2018년 새해의 첫날인 오늘(1일)은 하늘이 맑아 전국 대부분 지역에서 해돋이를 ...
#
#                                 title  \
# 0    몽고츠펑(内蒙古赤峰)중국의 홍산문화유적지에서 찡질방설계상담
# 1   파주 감악산의 명물인 출렁다리를 건너 만나본 감악산의 겨울.
# 2  What are you doing new year's eve?
# 3         서울) 코엑스 인터컨티넨탈 호텔 원더 아워 즐기기
# 4      [오늘 날씨]2018년 첫날 '맑음'…해돋이 보러가세요
#
#                                                  url
# 0  https://blog.naver.com/PostView.nhn?blogId=yts...
# 1  https://blog.naver.com/PostView.nhn?blogId=sal...
# 2  https://blog.naver.com/PostView.nhn?blogId=wtw...
# ...

# %%
news=pd.read_csv(r'news.csv',index_col=0)

# %%
news.head(5)
# Out:
#          date                                            content      date.1  \
# 0  2018-01-01  무술년 첫날 청명내일밤 슈퍼문 “소원 빌어보세요” 뉴스리뷰 앵커  힘차게 떠오르는 ...  2018-01-01
# 1  2018-01-01  날씨 새해 첫 출근날 맑고 쌀쌀찬바람 쌩쌩 새해 첫날인 오늘 종일 안개와 미세먼지 ...  2018-01-01
# 2  2018-01-01      새해 첫날인 일은 다소 쌀쌀하면서도 맑은 날씨를 보여 체육행사에 참여하거나 ...  2018-01-01
# 3  2018-01-01      화요일인 일은 전국이 대체로 맑다가 밤에 구름이 많아질 전망이다 기온은 평년...  2018-01-01
# 4  2018-01-01    이데일리 그동안 봄철 등 일부 계절에만 팔리던 ‘틈새가전’ 공기청정기가 미세먼지...  2018-01-01
#
#    name                            title  \
# 0  연합뉴스     무술년 첫날 청명…내일밤 슈퍼문 “소원 빌어보세요”
# 1  연합뉴스       [날씨] 새해 첫 출근날 맑고 쌀쌀…찬바람 쌩쌩
# 2  연합뉴스  새해 첫날 체육행사·야외활동 나온 시민들로 도심 '북적'
# 3  연합뉴스   [내일날씨] 바람불어 체감온도 '뚝'…맑다가 밤에 구름
# 4  이데일리     '무술년'도 미세먼지, 공기청정기 상승세 이어질까?
#
#                                                  url
# 0  http://www.yonhapnewstv.co.kr/MYH2018010101460...
# 1  http://www.yonhapnewstv.co.kr/MYH2018010101000...
# 2  https://www.yna.co.kr/view/AKR2018010105120000...
# ...

# %%
news=news.drop('date.1',axis=1)

# %%
news.head(2)
# Out:
#          date                                            content  name  \
# 0  2018-01-01  무술년 첫날 청명내일밤 슈퍼문 “소원 빌어보세요” 뉴스리뷰 앵커  힘차게 떠오르는 ...  연합뉴스
# 1  2018-01-01  날씨 새해 첫 출근날 맑고 쌀쌀찬바람 쌩쌩 새해 첫날인 오늘 종일 안개와 미세먼지 ...  연합뉴스
#
#                           title  \
# 0  무술년 첫날 청명…내일밤 슈퍼문 “소원 빌어보세요”
# 1    [날씨] 새해 첫 출근날 맑고 쌀쌀…찬바람 쌩쌩
#
#                                                  url
# 0  http://www.yonhapnewstv.co.kr/MYH2018010101460...
# 1  http://www.yonhapnewstv.co.kr/MYH2018010101000...

# %%
news.to_csv(r'news.csv')

# %%
len(news['content'][0])
# Out:
# 768

# %%
news['title'][0]
# Out:
# '무술년 첫날 청명…내일밤 슈퍼문 “소원 빌어보세요”'

# %%
news['title'][1]
# Out:
# '[날씨] 새해 첫 출근날 맑고 쌀쌀…찬바람 쌩쌩'

# %% [markdown]
# ## 미세먼지 + - 매겨서, 프레이미 합치기.

# %% [markdown]
# ## 총 긍정/부정 날짜에서, 각각의 단어들을 분류한다.  --> 총 긍+부정 15개 이하는 삭제
#
# ## 뉴스랑 sns 합쳐서, 그 날의 +-를 결정. --> 1달 평균으로 내기.
#
# ## 중립은 조금 생각.

# %%
data=pd.read_excel('일별평균대기오염도_2018.xlsx')

# %%
sorted(data.측정일시.value_counts().index)
# Out:
# [20180101,
#  20180102,
#  20180103,
#  20180104,
#  20180105,
#  20180106,
#  20180107,
#  20180108,
#  20180109,
#  20180110,
#  20180111,
#  20180112,
#  20180113,
#  20180114,
#  20180115,
#  20180116,
#  20180117,
#  20180118,
#  20180119,
#  20180120,
#  20180121,
#  20180122,
#  20180123,
#  20180124,
#  20180125,
#  20180126,
#  20180127,
#  20180128,
#  20180129,
#  20180130,
#  20180131,
#  20180201,
#  20180202,
#  20180203,
#  20180204,
#  20180205,
#  20180206,
#  20180207,
#  20180208,
#  20180209,
#  20180210,
#  20180211,
#  20180212,
#  20180213,
#  20180214,
#  20180215,
#  20180216,
#  20180218,
#  20180219,
#  20180220,
#  20180221,
#  20180222,
#  20180223,
#  20180224,
#  20180225,
#  20180226,
#  20180227,
#  20180228,
#  20180301,
#  20180302,
#  20180303,
#  20180304,
#  20180305,
#  20180306,
#  20180307,
#  20180308,
#  20180309,
#  20180310,
#  20180311,
#  20180312,
#  20180313,
#  20180314,
#  20180315,
#  20180316,
#  20180317,
#  20180318,
# ...

# %%
data=data[(data['측정소명'] == '노원구') |  (data['측정소명'] =='종로구') | (data['측정소명'] =='서대문구')]

# %%
data.head(10)
# Out:
#          측정일시  측정소명  이산화질소농도(ppm)  오존농도(ppm)  이산화탄소농도(ppm)  아황산가스(ppm)  \
# 11   20180101   노원구         0.034      0.012           0.8       0.007
# 18   20180101  서대문구           NaN        NaN           NaN         NaN
# 31   20180101   종로구         0.029      0.016           0.6       0.007
# 50   20180102   노원구         0.033      0.014           0.8       0.006
# 57   20180102  서대문구           NaN        NaN           NaN         NaN
# 70   20180102   종로구         0.044      0.010           0.9       0.007
# 89   20180103   노원구         0.018      0.022           0.5       0.006
# 96   20180103  서대문구           NaN        NaN           NaN         NaN
# 109  20180103   종로구         0.025      0.016           0.6       0.007
# 128  20180104   노원구         0.031      0.014           0.6       0.006
#
#      미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 11        42.0        21.0
# 18         NaN         NaN
# 31        34.0        17.0
# 50        41.0        22.0
# 57         NaN         NaN
# ...

# %%
data=data.drop('이산화질소농도(ppm)',axis=1).drop('오존농도(ppm)',axis=1).drop('이산화탄소농도(ppm)',axis=1).drop('아황산가스(ppm)',axis=1)

# %% [markdown]
# # data

# %%
data = data.rename(columns = {'미세먼지(㎍/㎥)': 'pm10'})

# %%
data = data.rename(columns = {'초미세먼지(㎍/㎥)': 'pm2.5'})

# %%
sorted(data.pm10)
# Out:
# [6.0,
#  6.0,
#  6.0,
#  7.0,
#  7.0,
#  8.0,
#  8.0,
#  8.0,
#  8.0,
#  8.0,
#  8.0,
#  8.0,
#  8.0,
#  8.0,
#  9.0,
#  9.0,
#  9.0,
#  9.0,
#  9.0,
#  9.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  10.0,
#  11.0,
#  11.0,
#  11.0,
#  11.0,
#  11.0,
#  11.0,
#  12.0,
#  12.0,
#  12.0,
#  12.0,
#  13.0,
#  13.0,
#  13.0,
#  13.0,
#  14.0,
#  14.0,
#  14.0,
#  14.0,
#  15.0,
#  15.0,
#  15.0,
#  17.0,
#  17.0,
#  17.0,
#  17.0,
#  18.0,
#  18.0,
#  18.0,
#  18.0,
#  18.0,
#  18.0,
#  18.0,
#  18.0,
#  19.0,
#  19.0,
#  19.0,
#  19.0,
#  20.0,
#  20.0,
#  20.0,
#  20.0,
#  21.0,
#  21.0,
#  21.0,
#  21.0,
#  21.0,
#  21.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  23.0,
#  23.0,
#  23.0,
#  23.0,
#  24.0,
#  24.0,
#  24.0,
#  24.0,
#  24.0,
#  24.0,
#  24.0,
#  25.0,
#  25.0,
#  25.0,
#  25.0,
#  26.0,
#  26.0,
#  26.0,
#  26.0,
#  26.0,
#  26.0,
#  26.0,
#  26.0,
#  27.0,
#  27.0,
#  27.0,
#  27.0,
#  27.0,
#  27.0,
#  27.0,
#  28.0,
#  28.0,
# ...

# %%
dpp=data['pm2.5'].tolist().sort()

# %%
len(dpp)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-162-b660c71f9bae> in <module>
# ----> 1 len(dpp)
#
# TypeError: object of type 'NoneType' has no len()

# %%
data['label_pm10']=0
data['label_pm2.5']=0

# %%
data['label_pm10'][data['pm10']<= 30]=1

data['label_pm2.5'][data['pm2.5']<= 15]=1

data['label_pm10'][(data['pm10']<= 80) & (data['pm10']>=31)]=0
data['label_pm2.5'][(data['pm2.5']<= 35) & (data['pm2.5']>=16)]=0

data['label_pm10'][data['pm10']>= 81]=-1
data['label_pm2.5'][data['pm2.5']>= 36]=-1
# Out:
# C:\Users\Jungsk\AppData\Local\conda\conda\envs\study\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Jungsk\AppData\Local\conda\conda\envs\study\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Jungsk\AppData\Local\conda\conda\envs\study\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
data = data.dropna()

# %%
data.측정소명.value_counts()
# Out:
# 노원구     309
# 종로구     308
# 서대문구    275
# Name: 측정소명, dtype: int64

# %%
data.측정일시.value_counts().index
# Out:
# Int64Index([20181129, 20180213, 20180207, 20180208, 20180209, 20180210,
#             20180211, 20180212, 20180214, 20181212,
#             ...
#             20181106, 20181105, 20181104, 20181103, 20181102, 20181101,
#             20181031, 20181030, 20181029, 20181001],
#            dtype='int64', length=309)

# %%
no_data = data[data['측정소명']=='노원구']

# %%
jong_data = data[data['측정소명']=='종로구']

# %%
seo_data = data[data['측정소명']=='서대문구']

# %%
no_data
# Out:
#            측정일시 측정소명   pm10  pm2.5  label_pm10  label_pm2.5
# 11     20180101  노원구   42.0   21.0           0            0
# 50     20180102  노원구   41.0   22.0           0            0
# 89     20180103  노원구   36.0   19.0           0            0
# 128    20180104  노원구   47.0   26.0           0            0
# 167    20180105  노원구   63.0   40.0           0           -1
# 206    20180106  노원구   49.0   31.0           0            0
# 245    20180107  노원구   57.0   39.0           0           -1
# 284    20180108  노원구   61.0   43.0           0           -1
# 323    20180109  노원구   42.0   20.0           0            0
# 362    20180110  노원구   34.0   13.0           0            1
# 401    20180111  노원구   34.0   22.0           0            0
# 440    20180112  노원구   25.0   15.0           1            1
# 479    20180113  노원구   54.0   37.0           0           -1
# 518    20180114  노원구   77.0   57.0           0           -1
# 557    20180115  노원구   64.0   42.0           0           -1
# ...

# %%
jong_data
# Out:
#            측정일시 측정소명  pm10  pm2.5  label_pm10  label_pm2.5
# 31     20180101  종로구  34.0   17.0           0            0
# 70     20180102  종로구  36.0   22.0           0            0
# 109    20180103  종로구  31.0   19.0           0            0
# 148    20180104  종로구  39.0   24.0           0            0
# 187    20180105  종로구  51.0   35.0           0            0
# 226    20180106  종로구  38.0   27.0           0            0
# 265    20180107  종로구  47.0   36.0           0           -1
# 304    20180108  종로구  49.0   37.0           0           -1
# 343    20180109  종로구  37.0   19.0           0            0
# 382    20180110  종로구  27.0   13.0           1            1
# 421    20180111  종로구  30.0   22.0           1            0
# 460    20180112  종로구  21.0   14.0           1            1
# 499    20180113  종로구  48.0   37.0           0           -1
# 538    20180114  종로구  64.0   50.0           0           -1
# 577    20180115  종로구  63.0   45.0           0           -1
# ...

# %%
seo_data
# Out:
#            측정일시  측정소명   pm10  pm2.5  label_pm10  label_pm2.5
# 486    20180113  서대문구   93.0   10.0          -1            1
# 525    20180114  서대문구   75.0   36.0           0           -1
# 564    20180115  서대문구   83.0   42.0          -1           -1
# 603    20180116  서대문구  137.0   75.0          -1           -1
# 642    20180117  서대문구  134.0   77.0          -1           -1
# 681    20180118  서대문구  100.0   58.0          -1           -1
# 720    20180119  서대문구   65.0   27.0           0            0
# 759    20180120  서대문구  116.0   62.0          -1           -1
# 798    20180121  서대문구   62.0   32.0           0            0
# 837    20180122  서대문구   45.0   19.0           0            0
# 876    20180123  서대문구   24.0   11.0           1            1
# 915    20180124  서대문구   33.0   10.0           0            1
# 954    20180125  서대문구   25.0   11.0           1            1
# 993    20180126  서대문구   34.0   18.0           0            0
# ...

# %%
label_data = pd.DataFrame(columns=["date","label_pm10","label_pm2.5"])

# %%
label_data['date']=
# Out:
# Empty DataFrame
# Columns: [date, label_pm10, label_pm2.5]
# Index: []

# %%
data['label_pm10'].value_counts()
# Out:
#  0    502
#  1    388
# -1     37
# Name: label_pm10, dtype: int64

# %%
data[data['측정소명']=='노원구']['pm10'].value_counts()
# Out:
# 36.0     10
# 29.0     10
# 38.0     10
# 34.0      9
# 22.0      9
# 41.0      9
# 26.0      9
# 24.0      8
# 35.0      8
# 37.0      8
# 45.0      8
# 31.0      8
# 17.0      7
# 15.0      7
# 19.0      7
# 33.0      7
# 18.0      6
# 59.0      6
# 25.0      6
# 12.0      6
# 39.0      5
# 62.0      5
# 27.0      5
# 20.0      5
# 30.0      5
# 53.0      5
# 42.0      5
# 13.0      5
# 14.0      5
# 43.0      5
#          ..
# 54.0      3
# 52.0      3
# 74.0      2
# 66.0      2
# 56.0      2
# 86.0      2
# 55.0      2
# 76.0      2
# 10.0      2
# 63.0      2
# 50.0      2
# 68.0      2
# 84.0      2
# 61.0      1
# 114.0     1
# 77.0      1
# 91.0      1
# 106.0     1
# 89.0      1
# 65.0      1
# 87.0      1
# 75.0      1
# 9.0       1
# 32.0      1
# 8.0       1
# 51.0      1
# 96.0      1
# 111.0     1
# 44.0      1
# 99.0      1
# Name: pm10, Length: 75, dtype: int64

# %%
data['label_pm2.5'].value_counts()
# Out:
#  0    439
#  1    360
# -1    128
# Name: label_pm2.5, dtype: int64

# %%
data['label_pm2.5'][data['pm2.5']>= 76]
# Out:
# 596   -1
# 635   -1
# 642   -1
# 655   -1
# Name: label_pm2.5, dtype: int64

# %%
data['label_pm10'][data['pm10']>= 151]
# Out:
# Series([], Name: label_pm10, dtype: int64)

# %%
data.to_csv('labeling.csv')

# %%
da

# %%
df_daily['label_pm25'] = 0
df_daily['label_pm10'] = 0

df_temp0 = df_daily.loc[df_daily.pm25 <= 15,:]

df_temp0['label_pm25'] = 1

df_temp1 = df_daily.loc[df_daily.pm25 > 15,:]

df_temp1 = df_temp1.loc[df_temp1.pm25 <= 35,:]

df_temp1['label_pm25'] = 0



df_temp2 = df_daily.loc[df_daily.pm25 <= 75,:]

df_temp2 = df_temp2.loc[df_temp2.pm25 > 35,:]
df_temp2['label_pm25'] = 2
df_temp3 = df_daily.loc[df_daily.pm25 > 75,:]
df_temp3['label_pm25'] = 3
df_tp=df_temp0.append(df_temp1).append(df_temp2).append(df_temp3)
df_temp0 = df_tp.loc[df_tp.pm10 <= 30,:]
df_temp0['label_pm10'] = 0
df_temp1 = df_tp.loc[df_tp.pm10 > 30,:]
df_temp1 = df_temp1.loc[df_temp1.pm10 <= 80,:]
df_temp1['label_pm10'] = 1
df_temp2 = df_tp.loc[df_tp.pm10 <= 150,:]
df_temp2 = df_temp2.loc[df_temp2.pm10 > 80,:]
df_temp2['label_pm10'] = 2
df_temp3 = df_tp.loc[df_tp.pm10 > 150,:]
df_temp3['label_pm10'] = 3
df_daily=df_temp0.append(df_temp1).append(df_temp2).append(df_temp3)
# Out:
# C:\Users\Jungsk\AppData\Local\conda\conda\envs\study\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\Jungsk\AppData\Local\conda\conda\envs\study\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# C:\Users\Jungsk\AppData\Local\conda\conda\envs\study\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# ...

# %%
df_daily.head(5)
# Out:
#           측정일시  측정소명  미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)  pm25  pm10  label_pm25  \
# 2429  20180305   노원구       10.0         5.0  10.0   5.0           0
# 2436  20180305  서대문구        6.0         3.0   6.0   3.0           0
# 2449  20180305   종로구        8.0         5.0   8.0   5.0           0
# 2553  20180308  서대문구       14.0        14.0  14.0  14.0           0
# 2858  20180316   노원구       15.0         6.0  15.0   6.0           0
#
#       label_pm10
# 2429           0
# 2436           0
# 2449           0
# 2553           0
# 2858           0

# %%
df_daily.df_daily['']

# %%
df_daily
# Out:
#            측정일시  측정소명  미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)  pm2.5  pm10  label_pm2.5  \
# 2429   20180305   노원구       10.0         5.0   10.0   5.0            1
# 2436   20180305  서대문구        6.0         3.0    6.0   3.0            1
# 2449   20180305   종로구        8.0         5.0    8.0   5.0            1
# 2553   20180308  서대문구       14.0        14.0   14.0  14.0            1
# 2858   20180316   노원구       15.0         6.0   15.0   6.0            1
# 2865   20180316  서대문구       10.0         6.0   10.0   6.0            1
# 2878   20180316   종로구       12.0         6.0   12.0   6.0            1
# 3560   20180423   노원구       11.0         7.0   11.0   7.0            1
# 3567   20180423  서대문구        8.0         7.0    8.0   7.0            1
# 3580   20180423   종로구        9.0         6.0    9.0   6.0            1
# 3599   20180424   노원구       12.0         5.0   12.0   5.0            1
# 3606   20180424  서대문구        8.0         4.0    8.0   4.0            1
# ...

# %%
df_daily.columns.values[6]='label_pm2.5'
df_daily.columns.values[4]='pm2.5'

# %%
df_daily.columns.values[2]='pm10'

# %%
df_daily.columns.values[3]='pm2.5'

# %%
df_daily['label_pm2.5']=0
df_daily['label_pm10']=0

# %%
df_daily.head(5)
# Out:
#           측정일시  측정소명  pm10  pm2.5  label_pm2.5  label_pm10
# 2429  20180305   노원구  10.0    5.0            1           1
# 2436  20180305  서대문구   6.0    3.0            1           1
# 2449  20180305   종로구   8.0    5.0            1           1
# 2553  20180308  서대문구  14.0   14.0            1           1
# 2858  20180316   노원구  15.0    6.0            1           1

# %%
df_daily.columns.values[4]
# Out:
# 'pm25'

# %%
df_daily.head(4)
# Out:
#           측정일시  측정소명  pm10  pm2.5  label_pm2.5  label_pm10
# 2429  20180305   노원구  10.0    5.0            1           1
# 2436  20180305  서대문구   6.0    3.0            1           1
# 2449  20180305   종로구   8.0    5.0            1           1
# 2553  20180308  서대문구  14.0   14.0            1           1

# %%
df_daily['pm10'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\conda\conda\envs\study\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'pm10'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-111-7e9c1d643043> in <module>
# ...

# %%
try:
    df_daily['label_pm10'][df_daily['pm10']<= 30]=1
except Exception as e:
    print(e)
# Out:
# 'pm10'

# %%
df_daily.columns
# Out:
# Index(['측정일시', '측정소명', 'pm10', 'pm2.5', 'label_pm2.5', 'label_pm10'], dtype='object')

# %%
df_daily['label_pm10'][df_daily['pm10']<= 30]=1
# Out:
# 2429     1
# 2436     1
# 2449     1
# 2553     1
# 2858     1
# 2865     1
# 2878     1
# 3560     1
# 3567     1
# 3580     1
# 3599     1
# 3606     1
# 3619     1
# 4074     1
# 4087     1
# 4165     1
# 4496     1
# 4503     1
# 4516     1
# 4535     1
# 4542     1
# 4555     1
# 4574     1
# 4581     1
# 4594     1
# 4971     1
# 4984     1
# 5003     1
# 5010     1
# 5023     1
#         ..
# 772      1
# 1578     1
# 2039     1
# 2046     1
# 2059     1
# 2085     1
# 2195     1
# 2202     1
# 2215     1
# 2234     1
# 2702     1
# 2709     1
# 2722     1
# 3443     1
# 3450     1
# 3489     1
# 3840     1
# 4386     1
# 4425     1
# 9905     1
# 9927     1
# 10851    1
# 10859    1
# 10874    1
# 11779    1
# 11955    1
# 12001    1
# 12009    1
# 12024    1
# 596      2
# Name: label_pm10, Length: 892, dtype: int64

# %%
df_daily['label_pm10'][df_daily['pm10']<= 30]=1

df_daily['label_pm2.5'][df_daily['pm2.5']<= 15]=1

df_daily['label_pm10'][(df_daily['pm10']<= 80) & (df_daily['pm10']>=31)]=0
df_daily['label_pm2.5'][(df_daily['pm2.5']<= 35) & (df_daily['pm2.5']>=16)]=0

df_daily['label_pm10'][df_daily['pm10']>= 81]=-1
df_daily['label_pm2.5'][df_daily['pm2.5']>= 36]=-1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\conda\conda\envs\study\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'pm10'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-167-357a243e0458> in <module>
# ...

# %%
df_daily['label_pm2.5'][df_daily['pm2.5']<= 15]=1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\conda\conda\envs\study\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'pm2.5'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-116-2f6f8ebe9e37> in <module>
# ...

# %%
data.head(5)
# Out:
#         측정일시  측정소명  미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)  pm2.5  pm10  label_pm2.5  \
# 11  20180101   노원구       42.0        21.0   42.0  21.0            0
# 18  20180101  서대문구        NaN         NaN    NaN   NaN            0
# 31  20180101   종로구       34.0        17.0   34.0  17.0            0
# 50  20180102   노원구       41.0        22.0   41.0  22.0            0
# 57  20180102  서대문구        NaN         NaN    NaN   NaN            0
#
#     label_pm10
# 11           0
# 18           0
# 31           0
# 50           0
# 57           0

# %%
data.head(5)
# Out:
#         측정일시  측정소명  미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)  pm2.5  pm10  label_pm2.5  \
# 11  20180101   노원구       42.0        21.0   42.0  21.0            0
# 18  20180101  서대문구        NaN         NaN    NaN   NaN            0
# 31  20180101   종로구       34.0        17.0   34.0  17.0            0
# 50  20180102   노원구       41.0        22.0   41.0  22.0            0
# 57  20180102  서대문구        NaN         NaN    NaN   NaN            0
#
#     label_pm10
# 11           0
# 18           0
# 31           0
# 50           0
# 57           0

# %%
data.drop('pm2.5',axis=1).drop('pm10',axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-132-c24b49f3d5e7> in <module>
# ----> 1 data.drop('pm2.5',axis=1).drop('pm10',axis=1)
#
# ~\AppData\Local\conda\conda\envs\study\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\AppData\Local\conda\conda\envs\study\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
df_daily.head(5)
# Out:
#           측정일시  측정소명  미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)  pm25  pm10  label_pm25  \
# 2429  20180305   노원구       10.0         5.0  10.0   5.0           1
# 2436  20180305  서대문구        6.0         3.0   6.0   3.0           1
# 2449  20180305   종로구        8.0         5.0   8.0   5.0           1
# 2553  20180308  서대문구       14.0        14.0  14.0  14.0           1
# 2858  20180316   노원구       15.0         6.0  15.0   6.0           1
#
#       label_pm10
# 2429           1
# 2436           1
# 2449           1
# 2553           1
# 2858           1

# %%
df_daily.loc[df_daily.pm25 <= 15,:]
# Out:
#            측정일시  측정소명  미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)  pm25  pm10  label_pm25  \
# 2429   20180305   노원구       10.0         5.0  10.0   5.0           1
# 2436   20180305  서대문구        6.0         3.0   6.0   3.0           1
# 2449   20180305   종로구        8.0         5.0   8.0   5.0           1
# 2553   20180308  서대문구       14.0        14.0  14.0  14.0           1
# 2858   20180316   노원구       15.0         6.0  15.0   6.0           1
# 2865   20180316  서대문구       10.0         6.0  10.0   6.0           1
# 2878   20180316   종로구       12.0         6.0  12.0   6.0           1
# 3560   20180423   노원구       11.0         7.0  11.0   7.0           1
# 3567   20180423  서대문구        8.0         7.0   8.0   7.0           1
# 3580   20180423   종로구        9.0         6.0   9.0   6.0           1
# 3599   20180424   노원구       12.0         5.0  12.0   5.0           1
# 3606   20180424  서대문구        8.0         4.0   8.0   4.0           1
# 3619   20180424   종로구        7.0         4.0   7.0   4.0           1
# ...

# %%
df_daily['label_pm25'] = df_daily.loc[df_daily.pm25 <= 15,:]

df_temp0['label_pm25'] = 1

# %%
df_daily=data

# %%
df_daily['pm2.5']=data['초미세먼지(㎍/㎥)']
df_daily['pm10']=data['미세먼지(㎍/㎥)']

# %%
df_daily.columns.

# %%
df_daily=df_daily.drop('pm2.5',axis=1).drop('pm10',axis=1)

# %%
df_daily.head(10)
# Out:
#           측정일시  측정소명  미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)  label_pm2.5  label_pm10
# 2429  20180305   노원구       10.0         5.0            1           1
# 2436  20180305  서대문구        6.0         3.0            1           1
# 2449  20180305   종로구        8.0         5.0            1           1
# 2553  20180308  서대문구       14.0        14.0            1           1
# 2858  20180316   노원구       15.0         6.0            1           1
# 2865  20180316  서대문구       10.0         6.0            1           1
# 2878  20180316   종로구       12.0         6.0            1           1
# 3560  20180423   노원구       11.0         7.0            1           1
# 3567  20180423  서대문구        8.0         7.0            1           1
# 3580  20180423   종로구        9.0         6.0            1           1

# %%
data=data.drop('이산화질소농도(ppm)')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-f51164d9704b> in <module>
# ----> 1 data=data.drop('이산화질소농도(ppm)')
#
# ~\AppData\Local\conda\conda\envs\study\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\AppData\Local\conda\conda\envs\study\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
data.iloc['측정일시','측정소명','미세먼지(㎍/㎥)','초미세먼지(㎍/㎥)']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\conda\conda\envs\study\lib\site-packages\pandas\core\indexing.py in _has_valid_tuple(self, key)
#     222             try:
# --> 223                 self._validate_key(k, i)
#     224             except ValueError:
#
# ~\AppData\Local\conda\conda\envs\study\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    2083             raise ValueError("Can only index by location with "
# -> 2084                              "a [{types}]".format(types=self._valid_types))
#    2085
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ...

# %%
노원=data['측정소명'] == '노원구'

# %% [markdown]
# ### 노원, 서대문,종로

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pd.merge(blog,news,how='outer',one='date')
