# %% [markdown]
# ## 10개 File을 , 하나로 합치기.
#
# ### 성연령 유동인구
# ### 시간대 유동인구

# %%
import pandas as pd

#def call_sum_file(file_type): # 1 for 성연령유동 2 for 시간대유동
    
    #call all files
    
    #flow age
f1804=pd.read_csv("C:\\Users\\Jungsk\\Downloads\\빅콘테스트 데이타\\유동인구데이터\\성연령유동\\노원_종로_FLOW_AGE_201804.csv",sep='|')
f1805=pd.read_csv("C:\\Users\\Jungsk\\Downloads\\빅콘테스트 데이타\\유동인구데이터\\성연령유동\\노원_종로_FLOW_AGE_201805.csv",sep='|')
f1806=pd.read_csv("C:\\Users\\Jungsk\\Downloads\\빅콘테스트 데이타\\유동인구데이터\\성연령유동\\노원_종로_FLOW_AGE_201806.csv",sep='|')
f1807=pd.read_csv("C:\\Users\\Jungsk\\Downloads\\빅콘테스트 데이타\\유동인구데이터\\성연령유동\\노원_종로_FLOW_AGE_201807.csv",sep='|')
f1808=pd.read_csv("C:\\Users\\Jungsk\\Downloads\\빅콘테스트 데이타\\유동인구데이터\\성연령유동\\노원_종로_FLOW_AGE_201808.csv",sep='|')
f1809=pd.read_csv("C:\\Users\\Jungsk\\Downloads\\빅콘테스트 데이타\\유동인구데이터\\성연령유동\\노원_종로_FLOW_AGE_201809.csv",sep='|')
f1810=pd.read_csv("C:\\Users\\Jungsk\\Downloads\\빅콘테스트 데이타\\유동인구데이터\\성연령유동\\노원_종로_FLOW_AGE_201810.csv",sep='|')
f1811=pd.read_csv("C:\\Users\\Jungsk\\Downloads\\빅콘테스트 데이타\\유동인구데이터\\성연령유동\\노원_종로_FLOW_AGE_201811.csv",sep='|')
f1812=pd.read_csv("C:\\Users\\Jungsk\\Downloads\\빅콘테스트 데이타\\유동인구데이터\\성연령유동\\노원_종로_FLOW_AGE_201812.csv",sep='|')
f1901=pd.read_csv("C:\\Users\\Jungsk\\Downloads\\빅콘테스트 데이타\\유동인구데이터\\성연령유동\\노원_종로_FLOW_AGE_201901.csv",sep='|')
f1902=pd.read_csv("C:\\Users\\Jungsk\\Downloads\\빅콘테스트 데이타\\유동인구데이터\\성연령유동\\노원_종로_FLOW_AGE_201902.csv",sep='|')
f1903=pd.read_csv("C:\\Users\\Jungsk\\Downloads\\빅콘테스트 데이타\\유동인구데이터\\성연령유동\\노원_종로_FLOW_AGE_201903.csv",sep='|')
    
    #flow time
    
p1804=pd.read_csv("C:\\Users\\Jungsk\\Downloads\\빅콘테스트 데이타\\유동인구데이터\\시간대유동\\노원_종로_FLOW_TIME_201804.csv",sep='|')
p1805=pd.read_csv("C:\\Users\\Jungsk\\Downloads\\빅콘테스트 데이타\\유동인구데이터\\시간대유동\\노원_종로_FLOW_TIME_201805.csv",sep='|')
p1806=pd.read_csv("C:\\Users\\Jungsk\\Downloads\\빅콘테스트 데이타\\유동인구데이터\\시간대유동\\노원_종로_FLOW_TIME_201806.csv",sep='|')
p1807=pd.read_csv("C:\\Users\\Jungsk\\Downloads\\빅콘테스트 데이타\\유동인구데이터\\시간대유동\\노원_종로_FLOW_TIME_201807.csv",sep='|')
p1808=pd.read_csv("C:\\Users\\Jungsk\\Downloads\\빅콘테스트 데이타\\유동인구데이터\\시간대유동\\노원_종로_FLOW_TIME_201808.csv",sep='|')
p1809=pd.read_csv("C:\\Users\\Jungsk\\Downloads\\빅콘테스트 데이타\\유동인구데이터\\시간대유동\\노원_종로_FLOW_TIME_201809.csv",sep='|')
p1810=pd.read_csv("C:\\Users\\Jungsk\\Downloads\\빅콘테스트 데이타\\유동인구데이터\\시간대유동\\노원_종로_FLOW_TIME_201810.csv",sep='|')
p1811=pd.read_csv("C:\\Users\\Jungsk\\Downloads\\빅콘테스트 데이타\\유동인구데이터\\시간대유동\\노원_종로_FLOW_TIME_201811.csv",sep='|')
p1812=pd.read_csv("C:\\Users\\Jungsk\\Downloads\\빅콘테스트 데이타\\유동인구데이터\\시간대유동\\노원_종로_FLOW_TIME_201812.csv",sep='|')
p1901=pd.read_csv("C:\\Users\\Jungsk\\Downloads\\빅콘테스트 데이타\\유동인구데이터\\시간대유동\\노원_종로_FLOW_TIME_201901.csv",sep='|')
p1902=pd.read_csv("C:\\Users\\Jungsk\\Downloads\\빅콘테스트 데이타\\유동인구데이터\\시간대유동\\노원_종로_FLOW_TIME_201902.csv",sep='|')
p1903=pd.read_csv("C:\\Users\\Jungsk\\Downloads\\빅콘테스트 데이타\\유동인구데이터\\시간대유동\\노원_종로_FLOW_TIME_201903.csv",sep='|')


    # append all files
    
성연령유동=f1804.append(f1805)
성연령유동=성연령유동.append(f1806)
성연령유동=성연령유동.append(f1806)
성연령유동=성연령유동.append(f1807)
성연령유동=성연령유동.append(f1808)
성연령유동=성연령유동.append(f1809)
성연령유동=성연령유동.append(f1810)
성연령유동=성연령유동.append(f1811)
성연령유동=성연령유동.append(f1812)
성연령유동=성연령유동.append(f1901)
성연령유동=성연령유동.append(f1902)
성연령유동=성연령유동.append(f1903)
    
시간대유동=p1804.append(p1805)
시간대유동=시간대유동.append(p1806)
시간대유동=시간대유동.append(p1806)
시간대유동=시간대유동.append(p1807)
시간대유동=시간대유동.append(p1808)
시간대유동=시간대유동.append(p1809)
시간대유동=시간대유동.append(p1810)
시간대유동=시간대유동.append(p1811)
시간대유동=시간대유동.append(p1812)
시간대유동=시간대유동.append(p1901)
시간대유동=시간대유동.append(p1902)
시간대유동=시간대유동.append(p1903)
    
# if file_type==1:
#     return 성연령유동
# elif file_type==2:
#     return 시간대유동

# %% [markdown]
# ## 자료를 DB나 코드로 합치고 보기 쉽게,
#
# ## 00~24 세로 칼럼명 합치기

# %%
import pandas as pd

성연령유동=pd.read_csv("C:\\Users\\Jungsk\\Downloads\\빅콘테스트 데이타\\유동인구데이터\\성연령유동\\성연령유동.csv",index_col=0)
시간대유동=pd.read_csv("C:\\Users\\Jungsk\\Downloads\\빅콘테스트 데이타\\유동인구데이터\\시간대유동\\시간대유동.csv",index_col=0)

# %%
시간대유동.head(5)
# Out:
#    STD_YM   STD_YMD    HDONG_CD HDONG_NM  TMST_00  TMST_01  TMST_02  TMST_03  \
# 0  201804  20180401  1111051500    청운효자동   609.11   447.82   301.75   217.03
# 1  201804  20180401  1111053000      사직동  1904.32  1319.04   951.80   779.08
# 2  201804  20180401  1111054000      삼청동   216.30   158.05    91.13    85.30
# 3  201804  20180401  1111055000      부암동  1300.61   904.38   670.74   433.02
# 4  201804  20180401  1111056000      평창동  2523.88  2168.69  1672.82  1300.87
#
#    TMST_04  TMST_05  ...   TMST_14  TMST_15  TMST_16  TMST_17  TMST_18  \
# 0   237.07   318.75  ...   3097.34  2550.96  2464.35  2327.44  1933.71
# 1   779.14  1355.75  ...  10166.17  9179.66  8899.18  8318.59  7009.69
# 2    86.76   146.87  ...   2361.17  2126.52  1998.35  1794.76  1281.02
# 3   571.34   771.25  ...   5155.72  4888.78  5111.07  5067.47  4148.24
# 4  1400.14  1686.09  ...  10460.65  9539.91  8973.38  7940.15  6992.54
#
#    TMST_19  TMST_20  TMST_21  TMST_22  TMST_23
# ...

# %%
성연령유동.head(5)
# Out:
#    STD_YM   STD_YMD    HDONG_CD HDONG_NM  MAN_FLOW_POP_CNT_0004  \
# 0  201804  20180401  1111051500    청운효자동                   0.05
# 1  201804  20180401  1111053000      사직동                   1.25
# 2  201804  20180401  1111054000      삼청동                   0.00
# 3  201804  20180401  1111055000      부암동                   0.00
# 4  201804  20180401  1111056000      평창동                   0.00
#
#    MAN_FLOW_POP_CNT_0509  MAN_FLOW_POP_CNT_1014  MAN_FLOW_POP_CNT_1519  \
# 0                  78.93                 403.26                 642.66
# 1                 262.54                1207.22                2177.88
# 2                  78.07                 255.24                 331.09
# 3                 228.50                 753.31                 981.54
# 4                 354.38                1500.63                1963.08
#
#    MAN_FLOW_POP_CNT_2024  MAN_FLOW_POP_CNT_2529  ...  WMAN_FLOW_POP_CNT_2529  \
# ...

# %%
시간대유동.columns
# Out:
# Index(['STD_YM', 'STD_YMD', 'HDONG_CD', 'HDONG_NM', 'TMST_00', 'TMST_01',
#        'TMST_02', 'TMST_03', 'TMST_04', 'TMST_05', 'TMST_06', 'TMST_07',
#        'TMST_08', 'TMST_09', 'TMST_10', 'TMST_11', 'TMST_12', 'TMST_13',
#        'TMST_14', 'TMST_15', 'TMST_16', 'TMST_17', 'TMST_18', 'TMST_19',
#        'TMST_20', 'TMST_21', 'TMST_22', 'TMST_23'],
#       dtype='object')

# %%
성연령유동.columns
# Out:
# Index(['STD_YM', 'STD_YMD', 'HDONG_CD', 'HDONG_NM', 'MAN_FLOW_POP_CNT_0004',
#        'MAN_FLOW_POP_CNT_0509', 'MAN_FLOW_POP_CNT_1014',
#        'MAN_FLOW_POP_CNT_1519', 'MAN_FLOW_POP_CNT_2024',
#        'MAN_FLOW_POP_CNT_2529', 'MAN_FLOW_POP_CNT_3034',
#        'MAN_FLOW_POP_CNT_3539', 'MAN_FLOW_POP_CNT_4044',
#        'MAN_FLOW_POP_CNT_4549', 'MAN_FLOW_POP_CNT_5054',
#        'MAN_FLOW_POP_CNT_5559', 'MAN_FLOW_POP_CNT_6064',
#        'MAN_FLOW_POP_CNT_6569', 'MAN_FLOW_POP_CNT_70U',
#        'WMAN_FLOW_POP_CNT_0004', 'WMAN_FLOW_POP_CNT_0509',
#        'WMAN_FLOW_POP_CNT_1014', 'WMAN_FLOW_POP_CNT_1519',
#        'WMAN_FLOW_POP_CNT_2024', 'WMAN_FLOW_POP_CNT_2529',
#        'WMAN_FLOW_POP_CNT_3034', 'WMAN_FLOW_POP_CNT_3539',
#        'WMAN_FLOW_POP_CNT_4044', 'WMAN_FLOW_POP_CNT_4549',
#        'WMAN_FLOW_POP_CNT_5054', 'WMAN_FLOW_POP_CNT_5559',
#        'WMAN_FLOW_POP_CNT_6064', 'WMAN_FLOW_POP_CNT_6569',
#        'WMAN_FLOW_POP_CNT_70U'],
#       dtype='object')

# %%
def column_0024(df):
    df=df.rename(columns={'MAN_FLOW_POP_CNT_0004':'MAN_FLOW_POP_CNT_0024'})
    df=df.rename(columns={'WMAN_FLOW_POP_CNT_0004':'WMAN_FLOW_POP_CNT_0024'})
    
    df['MAN_FLOW_POP_CNT_0024']=df['MAN_FLOW_POP_CNT_0024']+df['MAN_FLOW_POP_CNT_0509']+df['MAN_FLOW_POP_CNT_1014']+df['MAN_FLOW_POP_CNT_1519']+df['MAN_FLOW_POP_CNT_2024']
    df['WMAN_FLOW_POP_CNT_0024']=df['WMAN_FLOW_POP_CNT_0024']+df['WMAN_FLOW_POP_CNT_0509']+df['WMAN_FLOW_POP_CNT_1014']+df['WMAN_FLOW_POP_CNT_1519']+df['WMAN_FLOW_POP_CNT_2024']
    
    df=df.drop(['MAN_FLOW_POP_CNT_0509'],axis=1)
    df=df.drop(['MAN_FLOW_POP_CNT_1014'],axis=1)
    df=df.drop(['MAN_FLOW_POP_CNT_1519'],axis=1)
    df=df.drop(['MAN_FLOW_POP_CNT_2024'],axis=1)

    df=df.drop(['WMAN_FLOW_POP_CNT_0509'],axis=1)
    df=df.drop(['WMAN_FLOW_POP_CNT_1014'],axis=1)
    df=df.drop(['WMAN_FLOW_POP_CNT_1519'],axis=1)
    df=df.drop(['WMAN_FLOW_POP_CNT_2024'],axis=1)

    return df

# %%
column_0024(성연령유동)
# Out:
#       STD_YM   STD_YMD    HDONG_CD     HDONG_NM  MAN_FLOW_POP_CNT_0024  \
# 0     201804  20180401  1111051500        청운효자동                2109.14
# 1     201804  20180401  1111053000          사직동                7725.78
# 2     201804  20180401  1111054000          삼청동                1318.72
# 3     201804  20180401  1111055000          부암동                3579.12
# 4     201804  20180401  1111056000          평창동                6411.16
# 5     201804  20180401  1111057000          무악동                1131.72
# 6     201804  20180401  1111058000          교남동                1437.87
# 7     201804  20180401  1111060000          가회동                1242.84
# 8     201804  20180401  1111061500  종로1.2.3.4가동               21600.61
# 9     201804  20180401  1111063000      종로5.6가동                6562.66
# 10    201804  20180401  1111064000          이화동                5186.10
# 11    201804  20180401  1111065000          혜화동                6561.27
# ...

# %%
SIGU=[]
GUDO=[]
DONG=[]
ls=[]
def 성연령_col_수정(df):
    s=df['HDONG_CD'].tolist()
    for i in s:
        ss=str(i)
        sigu=ss[:4]# 1135
        SIGU.append(sigu)
        gdong=ss[2:8] # 35****  구,동 코드
        GUDO.append(gdong)
        dong=ss[:8]
        DONG.append(dong)
    df['SIGU_CD']=SIGU
    df['GUDO_CD']=GUDO
    df['HDONG_CD']=DONG
    ls=df.columns.tolist()
    df2=pd.DataFrame(df,columns=ls[0:2]+ls[-2:]+ls[2:-2])
    return df2

# %%
성연령_col_수정(성연령유동)
# Out:
#       STD_YM   STD_YMD SIGU_CD GUDO_CD  HDONG_CD     HDONG_NM  \
# 0     201804  20180401    1111  110515  11110515        청운효자동
# 1     201804  20180401    1111  110530  11110530          사직동
# 2     201804  20180401    1111  110540  11110540          삼청동
# 3     201804  20180401    1111  110550  11110550          부암동
# 4     201804  20180401    1111  110560  11110560          평창동
# 5     201804  20180401    1111  110570  11110570          무악동
# 6     201804  20180401    1111  110580  11110580          교남동
# 7     201804  20180401    1111  110600  11110600          가회동
# 8     201804  20180401    1111  110615  11110615  종로1.2.3.4가동
# 9     201804  20180401    1111  110630  11110630      종로5.6가동
# 10    201804  20180401    1111  110640  11110640          이화동
# 11    201804  20180401    1111  110650  11110650          혜화동
# 12    201804  20180401    1111  110670  11110670         창신1동
# 13    201804  20180401    1111  110680  11110680         창신2동
# ...

# %%
SIGU=[]
GUDO=[]
DONG=[]
ls=[]
def 시간대_col_수정(df):
    s=df['HDONG_CD'].tolist()
    for i in s:
        ss=str(i)
        sigu=ss[:4]# 1135
        SIGU.append(sigu)
        gdong=ss[2:8] # 35****  구,동 코드
        GUDO.append(gdong)
        dong=ss[:8]
        DONG.append(dong)
    df['SIGU_CD']=SIGU
    df['GUDO_CD']=GUDO
    df['HDONG_CD']=DONG
    ls=df.columns.tolist()
    df3=pd.DataFrame(df,columns=ls[0:2]+ls[-2:]+ls[2:-2])
    return df3

# %%
시간대_col_수정(시간대유동)
# Out:
#       STD_YM   STD_YMD SIGU_CD GUDO_CD  HDONG_CD     HDONG_NM  TMST_00  \
# 0     201804  20180401    1111  110515  11110515        청운효자동   609.11
# 1     201804  20180401    1111  110530  11110530          사직동  1904.32
# 2     201804  20180401    1111  110540  11110540          삼청동   216.30
# 3     201804  20180401    1111  110550  11110550          부암동  1300.61
# 4     201804  20180401    1111  110560  11110560          평창동  2523.88
# 5     201804  20180401    1111  110570  11110570          무악동   332.06
# 6     201804  20180401    1111  110580  11110580          교남동   528.17
# 7     201804  20180401    1111  110600  11110600          가회동   258.39
# 8     201804  20180401    1111  110615  11110615  종로1.2.3.4가동  4078.65
# 9     201804  20180401    1111  110630  11110630      종로5.6가동  1350.90
# 10    201804  20180401    1111  110640  11110640          이화동   741.76
# 11    201804  20180401    1111  110650  11110650          혜화동  1482.43
# ...

# %% [markdown]
# ## Class 로 사용...!!!

# %%
class col_revision():
    def __init__(self,df):
        self.df=df
        
    def col_수정(self,df):
        self.df=df
        
        SIGU=[]
        GUDO=[]
        DONG=[]
        ls=[]
        s=df['HDONG_CD'].tolist()
        for i in s:
            ss=str(i)
            sigu=ss[:4]# 1135
            SIGU.append(sigu)
            gdong=ss[2:8] # 35****  구,동 코드
            GUDO.append(gdong)
            dong=ss[:8]
            DONG.append(dong)
        df['SIGU_CD']=SIGU
        df['GUDO_CD']=GUDO
        df['HDONG_CD']=DONG
        ls=df.columns.tolist()
        df2=pd.DataFrame(df,columns=ls[0:2]+ls[-2:]+ls[2:-2])
        return df2
    
#     def 성연령유동_0024(self,df):
#         self.df=df
#         if self.df=='성연령유동':
#             return column_0024(df)
#         else:
#             pass

# %%
dd=col_revision(성연령유동)

# %%
dd.col_수정(성연령유동)
# Out:
#       STD_YM   STD_YMD SIGU_CD GUDO_CD  HDONG_CD     HDONG_NM  \
# 0     201804  20180401    1111  110515  11110515        청운효자동
# 1     201804  20180401    1111  110530  11110530          사직동
# 2     201804  20180401    1111  110540  11110540          삼청동
# 3     201804  20180401    1111  110550  11110550          부암동
# 4     201804  20180401    1111  110560  11110560          평창동
# 5     201804  20180401    1111  110570  11110570          무악동
# 6     201804  20180401    1111  110580  11110580          교남동
# 7     201804  20180401    1111  110600  11110600          가회동
# 8     201804  20180401    1111  110615  11110615  종로1.2.3.4가동
# 9     201804  20180401    1111  110630  11110630      종로5.6가동
# 10    201804  20180401    1111  110640  11110640          이화동
# 11    201804  20180401    1111  110650  11110650          혜화동
# 12    201804  20180401    1111  110670  11110670         창신1동
# 13    201804  20180401    1111  110680  11110680         창신2동
# ...

# %%
dd.col_수정(시간대유동)
# Out:
#       STD_YM   STD_YMD SIGU_CD GUDO_CD  HDONG_CD     HDONG_NM  TMST_00  \
# 0     201804  20180401    1111  110515  11110515        청운효자동   609.11
# 1     201804  20180401    1111  110530  11110530          사직동  1904.32
# 2     201804  20180401    1111  110540  11110540          삼청동   216.30
# 3     201804  20180401    1111  110550  11110550          부암동  1300.61
# 4     201804  20180401    1111  110560  11110560          평창동  2523.88
# 5     201804  20180401    1111  110570  11110570          무악동   332.06
# 6     201804  20180401    1111  110580  11110580          교남동   528.17
# 7     201804  20180401    1111  110600  11110600          가회동   258.39
# 8     201804  20180401    1111  110615  11110615  종로1.2.3.4가동  4078.65
# 9     201804  20180401    1111  110630  11110630      종로5.6가동  1350.90
# 10    201804  20180401    1111  110640  11110640          이화동   741.76
# 11    201804  20180401    1111  110650  11110650          혜화동  1482.43
# ...
